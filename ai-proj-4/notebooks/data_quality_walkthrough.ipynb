# %% [markdown]
# # Data Quality Walkthrough
# Explore sample dataset and validation helpers.

# %%
import pandas as pd
from pathlib import Path
sample = Path('../data/samples/retail_sales.csv')
df = pd.read_csv(sample)
df.head()

# %%
df.isna().mean()

# %%
df.describe()
